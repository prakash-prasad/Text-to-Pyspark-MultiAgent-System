# %%
column_dict = {
    "UserID": {
        "column_name": "UserID",
        "column_desc": "A unique identifier for each user.",
        "column_type": "int",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "1",
            "2",
            "3",
            "4",
            "5"
        ],
        "data_distribution": [
            [
                "count",
                300.0
            ],
            [
                "min",
                1.0
            ],
            [
                "25%",
                75.75
            ],
            [
                "50%",
                150.5
            ],
            [
                "75%",
                225.25
            ],
            [
                "max",
                300.0
            ],
            [
                "mean",
                150.5
            ],
            [
                "std",
                86.74675786448736
            ]
        ]
    },
    "UserName": {
        "column_name": "UserName",
        "column_desc": "The user's chosen username.",
        "column_type": "string",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "yildirimsatrettin",
            "tarhanhasgul",
            "corlumestur",
            "unalsensoy",
            "abid26"
        ],
        "data_distribution": [
            [
                "unique_count",
                298
            ],
            [
                "top_5_values",
                [
                    [
                        "bilgendumanli",
                        2
                    ],
                    [
                        "skaradeniz",
                        2
                    ],
                    [
                        "gulagainonu",
                        1
                    ],
                    [
                        "corlugulsevil",
                        1
                    ],
                    [
                        "kubranulker",
                        1
                    ]
                ]
            ]
        ]
    },
    "Email": {
        "column_name": "Email",
        "column_desc": "The user's email address.",
        "column_type": "string",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "muhammetyaman@example.net",
            "zenginsavki@example.org",
            "fedentevetoglu@example.org",
            "cbilgin@example.net",
            "sayin23@example.com"
        ],
        "data_distribution": [
            [
                "unique_count",
                299
            ],
            [
                "top_5_values",
                [
                    [
                        "tarhannas@example.com",
                        2
                    ],
                    [
                        "muhammetyaman@example.net",
                        1
                    ],
                    [
                        "gokcilulker@example.com",
                        1
                    ],
                    [
                        "laze91@example.org",
                        1
                    ],
                    [
                        "cagaseven@example.com",
                        1
                    ]
                ]
            ]
        ]
    },
    "User_Gender": {
        "column_name": "User_Gender",
        "column_desc": "The gender of the user (e.g., Male, Female, Other).",
        "column_type": "string",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "Female",
            "Male",
            "Other"
        ],
        "data_distribution": [
            [
                "unique_count",
                3
            ],
            [
                "top_5_values",
                [
                    [
                        "Female",
                        151
                    ],
                    [
                        "Male",
                        136
                    ],
                    [
                        "Other",
                        13
                    ]
                ]
            ]
        ]
    },
    "User_BirthDate": {
        "column_name": "User_BirthDate",
        "column_desc": "The user's date of birth, stored as a string in DD-MM-YYYY format.",
        "column_type": "date (stored as string)",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "04-11-1989",
            "09-11-1992",
            "07-07-1965",
            "14-07-1967",
            "07-05-2005"
        ],
        "data_distribution": [
            [
                "count",
                300
            ],
            [
                "min",
                "1960-01-24 00:00:00"
            ],
            [
                "25%",
                "1974-02-14 00:00:00"
            ],
            [
                "50%",
                "1984-05-05 12:00:00"
            ],
            [
                "75%",
                "1996-08-07 06:00:00"

            ],
            [
                "max",
                "2010-12-19 00:00:00"
            ]
        ]
    },
    "User_Country": {
        "column_name": "User_Country",
        "column_desc": "The user's country of residence.",
        "column_type": "string",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "Germany",
            "France",
            "USA",
            "United Kingdom",
            "Turkey"
        ],
        "data_distribution": [
            [
                "unique_count",
                6
            ],
            [
                "top_5_values",
                [
                    [
                        "United Kingdom",
                        57
                    ],
                    [
                        "Germany",
                        56
                    ],
                    [
                        "Turkey",
                        53
                    ],
                    [
                        "USA",
                        47
                    ],
                    [
                        "Japan",
                        45
                    ]
                ]
            ]
        ]
    },
    "RegistrationDate": {
        "column_name": "RegistrationDate",
        "column_desc": "The date the user registered, stored as a string in DD-MM-YYYY format.",
        "column_type": "date (stored as string)",
        "is_column_nullable": "false",
        "table_name": "users_EN",
        "table_desc": "Stores information about users who provide ratings, including their username, email, demographics (gender, birth date, country), and registration date.",
        "table_path": "data/users_EN.csv",
        "table_extenstion": "csv",
        "granularity_key": "UserID",
        "example_values": [
            "22-05-2024",
            "15-10-2020",
            "24-09-2015",
            "07-12-2016",
            "04-08-2019"
        ],
        "data_distribution": [
            [
                "count",
                300
            ],
            [
                "min",
                "2015-01-02 00:00:00"
            ],
            [
                "25%",
                "2017-10-19 00:00:00"
            ],
            [
                "50%",
                "2020-08-23 12:00:00"
            ],
            [
                "75%",
                "2023-05-19 06:00:00"
            ],
            [
                "max",
                "2025-12-26 00:00:00"
            ]
        ]
    }
}

# %%
# for each key in loaded_column_dict, replace it with some hash id, also make a csv of column name, table name (in this case table name is actors_EN), and this hash id
import json
import hashlib
import csv
new_dict = {}
column_names = column_dict.keys()
for col_name in column_names:
    col_meta = column_dict[col_name]
    hash_id = hashlib.md5(f"{col_meta['table_name']}_{col_name}".encode()).hexdigest()
    new_dict[hash_id] = column_dict[col_name]

# %%
# read column metadata json
with open('data/column_metadata.json', 'r') as f:
    loaded_column_dict = json.load(f)

# %%
# add these new entries from new_dict to loaded_column_dict
loaded_column_dict.update(new_dict)
# write back to column metadata json
with open('data/column_metadata.json', 'w') as f:
    json.dump(loaded_column_dict, f, indent=4)

# %%
# read column metadata json
with open('data/column_metadata.json', 'r') as f:
    loaded_column_dict = json.load(f)

len(loaded_column_dict)
# Out:
# 34
